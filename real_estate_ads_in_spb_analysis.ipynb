# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Пропуски-данных" data-toc-modified-id="Пропуски-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Пропуски данных</a></span><ul class="toc-item"><li><span><a href="#Пропуски-высоты-потолка-по-столбцу-ceiling_height" data-toc-modified-id="Пропуски-высоты-потолка-по-столбцу-ceiling_height-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Пропуски высоты потолка по столбцу ceiling_height</a></span></li><li><span><a href="#Пропуски-этажности-здания-по-столбцу-floors_total" data-toc-modified-id="Пропуски-этажности-здания-по-столбцу-floors_total-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Пропуски этажности здания по столбцу floors_total</a></span></li><li><span><a href="#Пропуски-жилой-площади-в-столбце-living_area-и-площади-кухни-kitchen_area" data-toc-modified-id="Пропуски-жилой-площади-в-столбце-living_area-и-площади-кухни-kitchen_area-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Пропуски жилой площади в столбце living_area и площади кухни kitchen_area</a></span></li><li><span><a href="#Пропуски-в-столбце-признака-аппартаментов-и-в-столбце-количества-балконов" data-toc-modified-id="Пропуски-в-столбце-признака-аппартаментов-и-в-столбце-количества-балконов-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Пропуски в столбце признака аппартаментов и в столбце количества балконов</a></span></li><li><span><a href="#Пропуски-в-локации" data-toc-modified-id="Пропуски-в-локации-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Пропуски в локации</a></span></li><li><span><a href="#Замена-типа-данных" data-toc-modified-id="Замена-типа-данных-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Замена типа данных</a></span></li></ul></li></ul></li><li><span><a href="#Рассчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Рассчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Рассчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-параметров-квартиры" data-toc-modified-id="Анализ-параметров-квартиры-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ параметров квартиры</a></span><ul class="toc-item"><li><span><a href="#Площадь-квартиры" data-toc-modified-id="Площадь-квартиры-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Площадь квартиры</a></span></li><li><span><a href="#Цена-квартиры" data-toc-modified-id="Цена-квартиры-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Цена квартиры</a></span></li><li><span><a href="#Количество-комнат" data-toc-modified-id="Количество-комнат-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Количество комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Высота потолков</a></span></li></ul></li><li><span><a href="#Время-продажи-квартиры" data-toc-modified-id="Время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Время продажи квартиры</a></span></li><li><span><a href="#Редкие-и-экстремальные-значения" data-toc-modified-id="Редкие-и-экстремальные-значения-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Редкие и экстремальные значения</a></span></li><li><span><a href="#Зависимость-цены-квартиры" data-toc-modified-id="Зависимость-цены-квартиры-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Зависимость цены квартиры</a></span></li><li><span><a href="#10-населенных-пунктов-с-наибольшим-числом-объявлений" data-toc-modified-id="10-населенных-пунктов-с-наибольшим-числом-объявлений-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>10 населенных пунктов с наибольшим числом объявлений</a></span></li><li><span><a href="#Расстояние-до-центра-Санкт-Петербурга" data-toc-modified-id="Расстояние-до-центра-Санкт-Петербурга-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Расстояние до центра Санкт-Петербурга</a></span></li><li><span><a href="#Анализ-квартир-в-центре-Санкт-Петербурга" data-toc-modified-id="Анализ-квартир-в-центре-Санкт-Петербурга-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Анализ квартир в центре Санкт-Петербурга</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений сервиса Яндекс Недвижимость
#
# Необходимо определить рыночную стоимость объектов недвижимости на основании установленных в результате исследования параметров, по данным сервиса за несколько лет.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Описние данных:**
#
# <br>airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# <br>balcony — число балконов
# <br>ceiling_height — высота потолков (м)
# <br>cityCenters_nearest — расстояние до центра города (м)
# <br>days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# <br>first_day_exposition — дата публикации
# <br>floor — этаж
# <br>floors_total — всего этажей в доме
# <br>is_apartment — апартаменты (булев тип)
# <br>kitchen_area — площадь кухни в квадратных метрах (м²)
# <br>last_price — цена на момент снятия с публикации
# <br>living_area — жилая площадь в квадратных метрах(м²)
# <br>locality_name — название населённого пункта
# <br>open_plan — свободная планировка (булев тип)
# <br>parks_around3000 — число парков в радиусе 3 км
# <br>parks_nearest — расстояние до ближайшего парка (м)
# <br>ponds_around3000 — число водоёмов в радиусе 3 км
# <br>ponds_nearest — расстояние до ближайшего водоёма (м)
# <br>rooms — число комнат
# <br>studio — квартира-студия (булев тип)
# <br>total_area — площадь квартиры в квадратных метрах (м²)
# <br>total_images — число фотографий квартиры в объявлении
# <br>Пояснение: апартаменты — это нежилые помещения, не относящиеся к жилому фонду, но имеющие необходимые условия для проживания.

# %% [markdown]
# ## Изучение данных из файла

# %%
# Импорт библиотек
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
from datetime import datetime

# %%
# Устранение научного отображения типа float, сообщений об ошибках библиотек
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.set_option('display.max_columns', 100)
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Чтение файла
data = pd.read_csv('/real_estate_data.csv', sep='\t')

# %%
# Общая оценка DataFrame 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# Количество строк 23699 22 столбца, имеются пропуски в части столбцов

# %%
# Вывод доли прoпусков по столбцам
empty_spaces_share = data.isna().mean().apply(lambda x: f"{x:.4f}")
empty_spaces_share
# Out:
# total_images            0.0000
# last_price              0.0000
# total_area              0.0000
# first_day_exposition    0.0000
# rooms                   0.0000
# ceiling_height          0.3880
# floors_total            0.0036
# living_area             0.0803
# floor                   0.0000
# is_apartment            0.8829
# studio                  0.0000
# open_plan               0.0000
# kitchen_area            0.0961
# balcony                 0.4861
# locality_name           0.0021
# airports_nearest        0.2338
# cityCenters_nearest     0.2329
# parks_around3000        0.2328
# parks_nearest           0.6591
# ponds_around3000        0.2328
# ponds_nearest           0.6156
# days_exposition         0.1342
# dtype: object

# %% [markdown]
# <br>Есть существенные пропуски в высоте потолков, жилой площади, площади кухни, флаге - аппартаменты, балконах, локации, сроке экспозиции.
# <br>В 14 столбцах есть пропуски с разной долей,
# <br>В следующих стролбцах доля пропусков одинакова:
# <br>airports_nearest
# <br>cityCenters_nearest
# <br>parks_around3000
# <br>ponds_around3000
# <br>Необходимо проверить совпадают ли пропуски по этим столбцам.
#
# <br>В столбцах с типом float, кроме столбцов орисывающих площадь квартир, цену и срок экспозиции, данные для удобства можно поменять на тип int, в столбце first_day_exposition нужно поменять тип с object на datetime.
#
# <br> В столбце is_apartment по смыслу должных находится данные типа bool вместо object

# %%
# Вывод сэмплов данных
data.head()
display(data.sample(10, random_state=1))
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 17338             5  3300000.00       47.00  2018-03-30T00:00:00      1
# 13876            12  2290000.00       40.00  2016-01-17T00:00:00      2
# 3586              0  5450000.00       53.80  2018-02-01T00:00:00      2
# 6495              1  5482990.00       66.10  2016-02-19T00:00:00      2
# 14431             5  4190000.00       54.00  2017-10-30T00:00:00      2
# 8363             13  5690000.00       41.70  2016-12-29T00:00:00      2
# 15270            15  4999000.00       42.00  2018-11-23T00:00:00      1
# 2143              4  3350000.00       55.50  2017-11-14T00:00:00      2
# 11284            17  3200000.00       48.00  2017-10-25T00:00:00      1
# 17095             8  5100000.00       50.20  2018-10-06T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 17338            3.00         10.00          nan      4          NaN   False
# ...

# %%
# Описание колличественных признаков
data.describe()
# Out:
#        total_images   last_price  total_area    rooms  ceiling_height  \
# count      23699.00     23699.00    23699.00 23699.00        14504.00
# mean           9.86   6541548.77       60.35     2.07            2.77
# std            5.68  10887013.27       35.65     1.08            1.26
# min            0.00     12190.00       12.00     0.00            1.00
# 25%            6.00   3400000.00       40.00     1.00            2.52
# 50%            9.00   4650000.00       52.00     2.00            2.65
# 75%           14.00   6800000.00       69.90     3.00            2.80
# max           50.00 763000000.00      900.00    19.00          100.00
#
#        floors_total  living_area    floor  kitchen_area  balcony  \
# count      23613.00     21796.00 23699.00      21421.00 12180.00
# mean          10.67        34.46     5.89         10.57     1.15
# std            6.60        22.03     4.89          5.91     1.07
# min            1.00         2.00     1.00          1.30     0.00
# ...

# %% [markdown]
# <br>В описании колличественных признаков есть потенциальные аномальные значения:
# <br>В высоте потолков есть минимальное значение - аномальный 1 м
# <br>В столбце total_area есть общая площадь в 12 кв.м, либо комната, либо перепланировка или старый фонд
# <br>В столбце rooms есть значение 0 комнат
# <br>В столбце floors_total есть значение 60 этажей
# <br>В столбце living_area есть значение жилой площади 2 кв.м
# <br>В столбце kitchen_area есть значение площади кухни 1.3 кв.м и 112 кв.м

# %%
#Вывод описания категориальных признаков
data.describe(include=[object])
# Out:
#        first_day_exposition is_apartment    locality_name
# count                 23699         2775            23650
# unique                 1491            2              364
# top     2018-02-01T00:00:00        False  Санкт-Петербург
# freq                    368         2725            15721

# %%
print(data['locality_name'].value_counts().head(20))
data['locality_name'].value_counts().tail(20)
# Out:
# Санкт-Петербург            15721
# посёлок Мурино               522
# посёлок Шушары               440
# Всеволожск                   398
# Пушкин                       369
# Колпино                      338
# посёлок Парголово            327
# Гатчина                      307
# деревня Кудрово              299
# Выборг                       237
# Петергоф                     201
# Сестрорецк                   183
# Красное Село                 178
# Кудрово                      173
# деревня Новое Девяткино      144
# Сертолово                    142
# Ломоносов                    133
# Кириши                       125
# Сланцы                       112
# Волхов                       111
# Name: locality_name, dtype: int64
# поселок Кирпичное                                    1
# посёлок Сумино                                       1
# поселок Дружноселье                                  1
# посёлок Плоское                                      1
# ...

# %% [markdown]
# Здесь интерес представляет частотность локации - в основном Санкт-Петербург. В описании локации присутствуют логические дубли типа: деревня Кудрово и Кудрово, поселок и посёлок. Данный столбец необходимо обработать.

# %% [markdown]
# ### Вывод

# %% [markdown]
# <br>Необходимо проанализировать столбцы с пропусками и принять решение по их заполнению, либо удалению. Возможно некоторые пропуски можно оставить без изменений
# <br>Также необходимо проанализировать аномально крайние значения по столбцам относящимся к параметрам квартиры.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Пропуски данных

# %% [markdown]
# #### Пропуски высоты потолка по столбцу ceiling_height

# %%
# Выборка пропусков в высоте потолков, в одноэтажных домах, не в Санкт-Петербурге
data_original = data.copy()
empty_ceiling = data.query('ceiling_height != ceiling_height')
len(empty_ceiling)
# Out:
# 9195

# %% [markdown]
# Пропуски высоты потолка в 9195 строках, 38.8%

# %%
# Вывод диаграммы размаха для оценки крайних значений
data['ceiling_height'].plot.box(ylim=(0, 9), autorange=True, figsize=(5,5))

# %%
# Заполнение пропусков высоты потолка на 2.5 м
data['ceiling_height'] = data['ceiling_height'].fillna(2.5)
len(data.query('ceiling_height != ceiling_height')) # Проверка отсутсвия пропусков
# Out:
# 0

# %% [markdown]
# Пропуски в столбце высоты потолка заполнены на минимальное значение официально установленное СНиП 31-01-2003 и более ранними советскими нормативами для жилых домов, которое составляет 2.5 метров и соответствует 1 квартилю, т.е. в представленной выборке потолок 2.5 метра и выше имеют до 25% квартир. Потолки меньше этого значения могут быть в частных домах в сельской местности, но для данного исследования это не существенно. Пропуски высоты потолка, вероятно не заполнялись пользователями, если этот показатель не рассматривался как существенный или способный увеличивать оценку квартиры.

# %%
data.describe()
# Out:
#        total_images   last_price  total_area    rooms  ceiling_height  \
# count      23699.00     23699.00    23699.00 23699.00        23699.00
# mean           9.86   6541548.77       60.35     2.07            2.67
# std            5.68  10887013.27       35.65     1.08            1.00
# min            0.00     12190.00       12.00     0.00            1.00
# 25%            6.00   3400000.00       40.00     1.00            2.50
# 50%            9.00   4650000.00       52.00     2.00            2.50
# 75%           14.00   6800000.00       69.90     3.00            2.70
# max           50.00 763000000.00      900.00    19.00          100.00
#
#        floors_total  living_area    floor  kitchen_area  balcony  \
# count      23613.00     21796.00 23699.00      21421.00 12180.00
# mean          10.67        34.46     5.89         10.57     1.15
# std            6.60        22.03     4.89          5.91     1.07
# min            1.00         2.00     1.00          1.30     0.00
# ...

# %% [markdown]
# #### Пропуски этажности здания по столбцу floors_total

# %%
# Выборка пропусков общей этажности здания
empty_floors_total = data.query('floors_total != floors_total')
len(empty_floors_total)
# Out:
# 86

# %%
empty_floors_total.count()
# Out:
# total_images            86
# last_price              86
# total_area              86
# first_day_exposition    86
# rooms                   86
# ceiling_height          86
# floors_total             0
# living_area             53
# floor                   86
# is_apartment             0
# studio                  86
# open_plan               86
# kitchen_area            39
# balcony                 47
# locality_name           85
# airports_nearest        76
# cityCenters_nearest     76
# parks_around3000        76
# parks_nearest           34
# ponds_around3000        76
# ponds_nearest           49
# days_exposition         77
# dtype: int64

# %% [markdown]
# Из 86 строк с пропусками общей этажности в 33 строках также пропущены значения жилой площади, в 47 - значения площади кухни, в 1 - локация, в 10 - расстояние до ближайшего аэропорта, центра города, число парков и водоемов в радиусе 3 км, в 52 - растояние до ближайшего парка и в 37 - растояние до ближайшего водоема.

# %%
# Удаление пропусков общей этажности
data.dropna(subset=['floors_total'], inplace=True)
len(data.query('floors_total != floors_total')) # Проверка
# Out:
# 0

# %% [markdown]
# Значение общей этажности необходимо для последующего анализа. Заполнение пропусков этого столбца по средним значениям других столбцов не имеет яроко выраженной логики. Т.к. число строк с пропусками невелико - 0.36% от выборки и таких строках одновременно присутствуют в разной доле пропуски по другим столбцам, пропуски были удалены из выборки.

# %%
data.describe()
# Out:
#        total_images   last_price  total_area    rooms  ceiling_height  \
# count      23613.00     23613.00    23613.00 23613.00        23613.00
# mean           9.87   6540555.46       60.34     2.07            2.67
# std            5.68  10901722.74       35.65     1.08            1.00
# min            0.00     12190.00       12.00     0.00            1.00
# 25%            6.00   3400000.00       40.00     1.00            2.50
# 50%            9.00   4650000.00       52.00     2.00            2.50
# 75%           14.00   6799000.00       69.80     3.00            2.70
# max           50.00 763000000.00      900.00    19.00          100.00
#
#        floors_total  living_area    floor  kitchen_area  balcony  \
# count      23613.00     21743.00 23613.00      21382.00 12133.00
# mean          10.67        34.46     5.88         10.56     1.15
# std            6.60        22.04     4.87          5.90     1.07
# min            1.00         2.00     1.00          1.30     0.00
# ...

# %% [markdown]
# #### Пропуски жилой площади в столбце living_area и площади кухни kitchen_area

# %%
# Выборка пропусков жилой площади
empty_living_area = data.query('living_area != living_area')
len(empty_living_area)
# Out:
# 1870

# %%
# Обновление доли пропусков после удаления пропусков этажности
data.isna().mean().apply(lambda x: f"{x:.4f}")
# Out:
# total_images            0.0000
# last_price              0.0000
# total_area              0.0000
# first_day_exposition    0.0000
# rooms                   0.0000
# ceiling_height          0.0000
# floors_total            0.0000
# living_area             0.0792
# floor                   0.0000
# is_apartment            0.8825
# studio                  0.0000
# open_plan               0.0000
# kitchen_area            0.0945
# balcony                 0.4862
# locality_name           0.0020
# airports_nearest        0.2343
# cityCenters_nearest     0.2333
# parks_around3000        0.2333
# parks_nearest           0.6593
# ponds_around3000        0.2333
# ponds_nearest           0.6163
# days_exposition         0.1343
# dtype: object

# %% [markdown]
# Пропуски в столбце жилой площади в 1870 строках, 7.92% от выборки.

# %%
# Выборка пропусков общей этажности здания
empty_kitchen_area = data.query('kitchen_area != kitchen_area')
len(empty_kitchen_area)
# Out:
# 2231

# %% [markdown]
# Пропуски в столбце площади кухни в 2231 строках 9.45% от выборки

# %%
# Категоризация столбца с общей площадью с шагом 10 метров
data['total_area_cat'] = pd.cut(data['total_area'],
       bins=np.linspace(10, 900, 90, dtype = int))
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20 13000000.00      108.00  2019-03-07T00:00:00      3
# 1             7  3350000.00       40.40  2018-12-04T00:00:00      1
# 2            10  5196000.00       56.00  2015-08-20T00:00:00      2
# 3             0 64900000.00      159.00  2015-07-24T00:00:00      3
# 4             2 10000000.00      100.00  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70         16.00        51.00      8          NaN   False
# 1            2.50         11.00        18.60      1          NaN   False
# 2            2.50          5.00        34.30      4          NaN   False
# 3            2.50         14.00          nan      9          NaN   False
# 4            3.03         14.00        32.00     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# В датафрейм добавен столбец категорий общей площади area_cat, группы с шагом 10 метров

# %%
# Замена пропусков в жилой площади и кухнях на медианы соответствющих категорий общей площади
median_living_area = data.groupby('total_area_cat')['living_area'].transform('median')
data['living_area'] = data['living_area'].fillna(median_living_area)
median_kitchen_area = data.groupby('total_area_cat')['kitchen_area'].transform('median')
data['kitchen_area'] = data['kitchen_area'].fillna(median_kitchen_area)

# %%
data.query('living_area != living_area or kitchen_area != kitchen_area')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3676             12 28789000.00      441.98  2019-01-23T00:00:00      4
# 22131            14 27000000.00      422.20  2018-10-18T00:00:00      5
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 3676             2.50          6.00          nan      6          NaN   False
# 22131            2.70         13.00          nan     11          NaN   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 3676       False         35.05      nan  Санкт-Петербург          20552.00
# 22131      False           nan      nan  Санкт-Петербург          46625.00
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 3676               5181.00              0.00            nan              0.00
# 22131             16554.00              0.00            nan              0.00
#
# ...

# %%
data.query('kitchen_area != kitchen_area')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22131            14 27000000.00      422.20  2018-10-18T00:00:00      5
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 22131            2.70         13.00          nan     11          NaN   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 22131      False           nan      nan  Санкт-Петербург          46625.00
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 22131             16554.00              0.00            nan              0.00
#
#        ponds_nearest  days_exposition total_area_cat
# 22131            nan              nan     (420, 430]

# %% [markdown]
# Замена пропусков жилой площади и кухни в оставшейся незаполненной строке на значения похожей по общей площади квартиры

# %%
data.query('total_area > 420 and total_area < 440')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 21955            19 130000000.00      431.00  2017-10-02T00:00:00      7
# 22131            14  27000000.00      422.20  2018-10-18T00:00:00      5
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 21955            3.70          8.00       220.00      5          NaN   False
# 22131            2.70         13.00          nan     11          NaN   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 21955      False         20.00     5.00  Санкт-Петербург               nan
# 22131      False           nan      nan  Санкт-Петербург          46625.00
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 21955                  nan               nan            nan               nan
# 22131             16554.00              0.00            nan              0.00
#
# ...

# %%
data['living_area'].fillna(220,inplace=True)
data['kitchen_area'].fillna(20,inplace=True)

# %%
data.query('living_area != living_area or kitchen_area != kitchen_area') # Контроль замены
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, total_area_cat]
# Index: []

# %%
# Замена площади кухни на 0 в студиях
data.loc[data['studio'] == True, 'kitchen_area'] = 0

# %%
# Контроль заполнения пропусков
data.describe()
# Out:
#        total_images   last_price  total_area    rooms  ceiling_height  \
# count      23613.00     23613.00    23613.00 23613.00        23613.00
# mean           9.87   6540555.46       60.34     2.07            2.67
# std            5.68  10901722.74       35.65     1.08            1.00
# min            0.00     12190.00       12.00     0.00            1.00
# 25%            6.00   3400000.00       40.00     1.00            2.50
# 50%            9.00   4650000.00       52.00     2.00            2.50
# 75%           14.00   6799000.00       69.80     3.00            2.70
# max           50.00 763000000.00      900.00    19.00          100.00
#
#        floors_total  living_area    floor  kitchen_area  balcony  \
# count      23613.00     23613.00 23613.00      23613.00 12133.00
# mean          10.67        34.66     5.88         10.40     1.15
# std            6.60        22.50     4.87          5.79     1.07
# min            1.00         2.00     1.00          0.00     0.00
# ...

# %%
data.query('living_area != living_area or kitchen_area != kitchen_area')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, total_area_cat]
# Index: []

# %% [markdown]
# <br>Проведена категоризация общей площади в столбец area_cat на группы с шагом 10 метров
# <br>Заполнены пропуски в жилой площади и кухни на медианное значения соответвующие группе общей площади для квартиры
# <br>Кухни в студиях приведены логически к значению 0
# <br>Значения квартилей и среднего до замены и после по столбцам жилой площади и площади кухни совпадают на 99%, что говорит о большой точности в логике замене пропусков, с учетом размаха значений общей площади даже для квартир одинаковых по числу комнат.

# %% [markdown]
# #### Пропуски в столбце признака аппартаментов и в столбце количества балконов

# %%
# Замена пропусков по аппартаментам и балконам
data['is_apartment'] = data['is_apartment'].fillna(False)
data['balcony'] = data['balcony'].fillna(0)

# %%
data.query('is_apartment != is_apartment') #Проверка заполнения пропусков
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, total_area_cat]
# Index: []

# %%
data.query('balcony != balcony')#Проверка заполнения пропусков
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, total_area_cat]
# Index: []

# %% [markdown]
# <br>Пропуски по столбцу is_apartment заполнены на значение False, этот признак всегда отмечают, если в объявлении - аппартаменты, поскольку аппартаменты относятся к коммерческой недвижимости, имеют налоговые и другие особенности.
# <br>Пропуски по столбцу balcony заменены на значение 0. Наличие балкона - плюс к оценке квартиры, поэтому его наличие всегда отмечают.

# %% [markdown]
# #### Пропуски в локации

# %%
data.query('locality_name != locality_name').count()
# Out:
# total_images            48
# last_price              48
# total_area              48
# first_day_exposition    48
# rooms                   48
# ceiling_height          48
# floors_total            48
# living_area             48
# floor                   48
# is_apartment            48
# studio                  48
# open_plan               48
# kitchen_area            48
# balcony                 48
# locality_name            0
# airports_nearest        40
# cityCenters_nearest     40
# parks_around3000        40
# parks_nearest           15
# ponds_around3000        40
# ponds_nearest           25
# days_exposition         47
# total_area_cat          48
# dtype: int64

# %%
# Удаление пропусков локации
data.dropna(subset=['locality_name'], inplace=True)
data.query('locality_name != locality_name')# Проверка удаления
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, total_area_cat]
# Index: []

# %% [markdown]
# Удалены строки с пропусками в локации. Количество таких строк 48, т.е. 0.2% выборки. Локация необходима для дальнейшего анализа

# %%
# Переименованы ближайшие пригороды
data['locality_name'] = data['locality_name'].replace('поселок', 'посёлок', regex=True)
data['locality_name'] = data['locality_name'].replace('деревня Кудрово', 'Кудрово', regex=True)
data['locality_name'] = data['locality_name'].replace('посёлок Мурино', 'Мурино', regex=True)

# %% [markdown]
# Переименованы ближайшие пригороды, ставшие городами, поселок и посёлок приведены к общему соответствию

# %%
data.describe()
# Out:
#        total_images   last_price  total_area    rooms  ceiling_height  \
# count      23565.00     23565.00    23565.00 23565.00        23565.00
# mean           9.88   6540058.26       60.32     2.07            2.67
# std            5.68  10910934.72       35.66     1.08            1.00
# min            0.00     12190.00       12.00     0.00            1.00
# 25%            6.00   3400000.00       40.00     1.00            2.50
# 50%            9.00   4646000.00       52.00     2.00            2.50
# 75%           14.00   6790000.00       69.70     3.00            2.70
# max           50.00 763000000.00      900.00    19.00          100.00
#
#        floors_total  living_area    floor  kitchen_area  balcony  \
# count      23565.00     23565.00 23565.00      23565.00 23565.00
# mean          10.68        34.65     5.88         10.40     0.59
# std            6.59        22.50     4.87          5.79     0.96
# min            1.00         2.00     1.00          0.00     0.00
# ...

# %%
# Обновление доли пропусков после удаления пропусков этажности
data.isna().mean().apply(lambda x: f"{x:.4f}")
# Out:
# total_images            0.0000
# last_price              0.0000
# total_area              0.0000
# first_day_exposition    0.0000
# rooms                   0.0000
# ceiling_height          0.0000
# floors_total            0.0000
# living_area             0.0000
# floor                   0.0000
# is_apartment            0.0000
# studio                  0.0000
# open_plan               0.0000
# kitchen_area            0.0000
# balcony                 0.0000
# locality_name           0.0000
# airports_nearest        0.2344
# cityCenters_nearest     0.2334
# parks_around3000        0.2334
# parks_nearest           0.6592
# ponds_around3000        0.2334
# ponds_nearest           0.6165
# days_exposition         0.1346
# total_area_cat          0.0000
# dtype: object

# %% [markdown]
# <br> Удалены 48 строк - 0.2% пропусков в локации
# <br> Обработаны строчные значения в локации, поселки приведены к посёлкам, города-пригороды, Кудрово и Мурино избавлены от статусов деревни и села. Обработка произведена для лучшей читаемости значений признака.

# %% [markdown]
# #### Замена типа данных

# %%
data['first_day_exposition'] = data['first_day_exposition'].astype("datetime64")
data['floors_total'] = data['floors_total'].astype('int64')
data['balcony'] = data['balcony'].astype('int64')

# %%
data.dtypes
# Out:
# total_images                     int64
# last_price                     float64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                     int64
# living_area                    float64
# floor                            int64
# is_apartment                      bool
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int64
# locality_name                   object
# airports_nearest               float64
# cityCenters_nearest            float64
# parks_around3000               float64
# parks_nearest                  float64
# ponds_around3000               float64
# ponds_nearest                  float64
# days_exposition                float64
# total_area_cat                category
# dtype: object

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20 13000000.00      108.00           2019-03-07      3
# 1             7  3350000.00       40.40           2018-12-04      1
# 2            10  5196000.00       56.00           2015-08-20      2
# 3             0 64900000.00      159.00           2015-07-24      3
# 4             2 10000000.00      100.00           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16        51.00      8         False   False
# 1            2.50            11        18.60      1         False   False
# 2            2.50             5        34.30      4         False   False
# 3            2.50            14        94.95      9         False   False
# 4            3.03            14        32.00     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <br>Заменены типы данных:
# <br>В столбце first_day_exposition c дробного - на datetime
# <br>В столбце floors_total и balcony с дробного - на целочисленный
# <br>Замены обусловлены логическими типами данных

# %% [markdown]
# <br>Обработаны пропуски:
# <br>В столбце ceiling_hight, высоты потолков заполнены минимальными нормативными значениями для жилых помещений - 2,5м
# <br>В столбце floors_total удалены пропуски общей этажности 86 строк, 0.36%, этажность необходима для дальнейшего анализа, логически связать с другими столбцами невозможно
# <br>В столбце living_area пропуски жилой площади заполнены медианой по соответствующим группам общего метража, 1870 строк, 7.92%
# <br>В столбце kitchen_area пропуски площади кухни заполнены медианой по cсоответствующим группам общего метража, 2231 строки, 9.45%
# <br>Пропуски в столбце is_apartment приведены к логичному значению False, т.к. признак аппартаментов указывают явно в силу отделного статуса
# <br>Пропуски в столбце balcony заполнены 0 значениями, наличие балкона увеличивает оценку, поэтому при наличии их заполняют.
# <br>Пропуски в столбце locality_name удалены, т.к. локация важное значение для анализа, 48 строк 0.2%
# <br>Пропуски по столбцам географической привязки оставлены без изменений, эти данные заполняются не пользователем а автоматически, возможна ошибка автоматизированной привязки по адресу, либо проблемы выгрузки, столбцы имеют примерно одинаковый процент пропусков. Информацию необходтио передать поставщику данных.
# <br>Пропуски по days_exposition, времени размещения объявления оставлены без изменений, эти показатели зависят от множества факторов. Возможно эти данные не прогружены, поэтому нет значения дней экспозиции 13,46% от выборки. Оставшихся данных по столбцу достаточно для анализа.

# %% [markdown]
# ## Рассчёты и добавление результатов в таблицу

# %%
# Добавление столбца с ценой квадратного метра
data['price_per_sqm'] = round(data['last_price'] / data['total_area'], 1)

# %%
# Добавление дня недели, месяца и года объявления
data['weekday'] = data['first_day_exposition'].dt.weekday
data['month'] = data['first_day_exposition'].dt.month
data['year'] = data['first_day_exposition'].dt.year

# %%
# Категоризация этажности в добавленном столбце floor_cat
data.loc[data['floor'] == 1, 'floor_cat'] = 'первый'
data.loc[data['floor'] == data['floors_total'], 'floor_cat'] = 'последний'
data.loc[data['floor_cat'].isna(), 'floor_cat'] = 'другой'

# %%
data['living_share'] = data['living_area'] / data['total_area']
data['kitchen_share'] = data['kitchen_area'] / data['total_area']

# %%
data.describe()
# Out:
#        total_images   last_price  total_area    rooms  ceiling_height  \
# count      23565.00     23565.00    23565.00 23565.00        23565.00
# mean           9.88   6540058.26       60.32     2.07            2.67
# std            5.68  10910934.72       35.66     1.08            1.00
# min            0.00     12190.00       12.00     0.00            1.00
# 25%            6.00   3400000.00       40.00     1.00            2.50
# 50%            9.00   4646000.00       52.00     2.00            2.50
# 75%           14.00   6790000.00       69.70     3.00            2.70
# max           50.00 763000000.00      900.00    19.00          100.00
#
#        floors_total  living_area    floor  kitchen_area  balcony  \
# count      23565.00     23565.00 23565.00      23565.00 23565.00
# mean          10.68        34.65     5.88         10.40     0.59
# std            6.59        22.50     4.87          5.79     0.96
# min            1.00         2.00     1.00          0.00     0.00
# ...

# %% [markdown]
# <br>Добавлены в таблицу данных:
# <br>Цена квадратного метра по строке
# <br>Столбцы с днем, месяцем и годом размещения объявления
# добавлены столбцы с долями жилой площади и кухни

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Анализ параметров квартиры

# %% [markdown]
# Для оценки параметров распределения будет применен межквартальный размах помноженый на 1,5 с обеих сторон распределения для выделения крайних или аномальных значений

# %%
# Функция для определения границ для boxplot на основе IQR*1.5
def border_markers(column):
    stat = data[column].describe() # Источник описательных характеристик 
    iqr = stat[6] - stat[4] # Определение межквартального размаха
    left_border = stat[4] - 1.5 * iqr # Вычесление левой границы
    right_border = stat[6] + 1.5 * iqr # Вычичление правой границы
    if left_border < stat[3]: left_border = stat[3] # Ограничение min значением
    if right_border > stat[7]: right_border = stat[7] # Ограничение max значением
    return [left_border, right_border]

# %% [markdown]
# #### Площадь квартиры

# %%
print('Границы крайних значений площади:',border_markers('total_area'))
# Out:
# Границы крайних значений площади: [12.0, 114.25]

# %%
# График размаха площади
plt.figure(figsize=(12, 2))
sns.boxplot(data['total_area'], palette='deep')
plt.xticks(np.arange(0,650,20))
plt.xlabel('Общая площадь, кв.м')
plt.xlim(0, 650)
plt.title('Диаграмма размаха площади')
plt.show()

# %%
# Описание столбца
data['total_area'].describe()
# Out:
# count   23565.00
# mean       60.32
# std        35.66
# min        12.00
# 25%        40.00
# 50%        52.00
# 75%        69.70
# max       900.00
# Name: total_area, dtype: float64

# %%
# Графиу распределения площади 
plt.figure(figsize=(10, 4))
sns.distplot(data['total_area'],kde=False, bins=100, color='darkblue')
plt.xticks(np.arange(0,200,10))
plt.xlim(12,200)
plt.grid(True)
plt.title('total_area')
plt.xlabel('Общая площадь, кв.м')
plt.ylabel('Частота')
plt.show()

# %%
data['extreme_area'] = (
    data['total_area'] > border_markers('total_area')[1]) | (data['total_area'] < 20)
print('Менее 20 кв.м.',data.query('total_area < 20').count()[3]) # количество ультра малогабаритных квартир
print('Более 114 кв.м',data.query('total_area > 114').count()[3]) # количество больших квартир
# Out:
# Менее 20 кв.м. 27
# Более 114 кв.м 1245

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.00      108.00           2019-03-07      3
# 1                 7  3350000.00       40.40           2018-12-04      1
# 2                10  5196000.00       56.00           2015-08-20      2
# 3                 0 64900000.00      159.00           2015-07-24      3
# 4                 2 10000000.00      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9  9700000.00      133.81           2017-03-21      3
# 23695            14  3100000.00       59.00           2018-01-15      3
# 23696            18  2500000.00       56.70           2018-02-11      2
# 23697            13 11475000.00       76.75           2017-03-28      2
# 23698             4  1350000.00       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %% [markdown]
# <br> 95% Квартир имеют площадь от 12 до 114 кв.м.
# <br>Минимальная площадь квартиры - 12 кв.м, такие квартиры могут быть в старом фонде, всего ультра малогабаритных квартир менее 20 кв.м - 27, или 0.11%
# <br>Максимальная площадь квартиры - 900 кв.м., это квартира на последнем этаже 25 этажного дома, возможно многоуровневый пентхаус.
# <br>Квартир более 114 кв.м. т.е. нетипично габаритных - 1245, или 5,28%
# <br>50% всех квартир на рынке - от 40 до 70 кв.м.
# <br>Средняя квартира - около 50 кв.м.
# Большой разброс в площади объясняется, ахитектурными тенденциями в разные периоды истории, причем доля ультрамалогабаритных квартир ничтожно мала по сравнению с долей большеметражных.

# %% [markdown]
# #### Цена квартиры

# %%
print('Границы крайних значений цены:',border_markers('last_price'))
# Out:
# Границы крайних значений цены: [12190.0, 11875000.0]

# %%
# График размаха цены
plt.figure(figsize=(14, 2))
sns.boxplot(data['last_price'], palette='deep')
plt.xticks(np.arange(0,100000000,2000000),rotation=90)
plt.xlabel('Цена в десятках млн.р')
plt.xlim(0, 100000000)
plt.title('Диаграмма размаха цены')
plt.show()

# %%
# Описание столбца
data['last_price'].describe()
# Out:
# count       23565.00
# mean      6540058.26
# std      10910934.72
# min         12190.00
# 25%       3400000.00
# 50%       4646000.00
# 75%       6790000.00
# max     763000000.00
# Name: last_price, dtype: float64

# %%
# Диаграмма распределения цен
plt.figure(figsize=(10, 4))
sns.distplot(data['last_price'],kde=False, bins=2000, color='darkblue')
plt.xticks(np.arange(0,20000000,1000000))
plt.xlim(10000,20000000)
plt.grid(True)
plt.title('Диаграмма распределения цены ')
plt.xlabel('Цена в десятках млн р.')
plt.ylabel('Частота')
plt.show()

# %%
# Оценка аномально крайних значений
data.query('last_price < 3400000 or last_price > 11875000').sort_values('last_price').head()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 8793              7    12190.00      109.00           2019-03-20      2
# 17456             7   430000.00       30.40           2019-04-22      1
# 14911             5   430000.00       54.00           2018-06-26      2
# 16274            18   440000.00       40.00           2018-07-10      1
# 5698              7   450000.00       42.00           2017-07-31      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 8793             2.75            25        32.00     25         False   False
# 17456            2.50             2        16.00      1         False   False
# 14911            2.50             3        32.00      3         False   False
# 16274            2.50             5        17.40      1         False   False
# 5698             2.50             1        23.00      1         False   False
#
# ...

# %%
data.query("last_price < 1000000 and locality_name != 'Санкт-Петербург'") # Выборка объектов в СПб с ценой менее 1 млн.р.
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 164               6   800000.00       40.30           2018-06-25      2
# 247               7   650000.00       31.00           2017-01-20      1
# 259               6   900000.00       30.00           2017-11-21      1
# 268               7   650000.00       46.00           2018-03-15      2
# 293               2   900000.00       42.80           2017-06-14      2
# ...             ...         ...         ...                  ...    ...
# 23067             8   600000.00       31.80           2019-04-24      1
# 23153             9   650000.00       41.00           2017-10-13      2
# 23354            18   900000.00       42.60           2018-02-26      2
# 23484            11   470000.00       44.50           2018-07-02      2
# 23643             1   660000.00       45.00           2019-02-19      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# ...

# %%
data['extreme_price'] = (
    data['last_price'] > border_markers('last_price')[1]) | (data['last_price'] < 1000000)
print('Очень Дешевые',data.query('last_price < 1000000').count()[3])
print('Очень дорогие квартиры',data.query('last_price > 11875000').count()[3])
# Out:
# Очень Дешевые 225
# Очень дорогие квартиры 2046

# %% [markdown]
# <br>Самая недорогая квартира в выборке - очевидная ошибка в виду низкой цены в 12190 р. за 109 кв.м. Настоящее минамальное значение сразу у двух квартир в отдаленных районах Лен.области - 430000 р, там такие квартиры вполне реальны.
# <br>Самая дорогая квартира - не самая габаритная, но ближе к центру города, также на последнем этаже.
# <br>Доля очень дорогих квартир, которых 2046 - 8.68%
# <br>Доля очень дешевых квартир, которых 225 - 0.95% - практически все они в отдаленных районах Лен.области либо в селах
# <br>50% всех квартир стоят от 3.4 до 6.79 млн.р., средняя квартира стоит 6.54 млн.р
# <br>Более 90% всех квартир не дешевле 1 и не дороже 11.87 млн.р.

# %% [markdown]
# #### Количество комнат

# %%
print('Границы крайних значений числа комнат:',border_markers('rooms'))
# Out:
# Границы крайних значений числа комнат: [0.0, 6.0]

# %%
# График размаха комнат
plt.figure(figsize=(14, 2))
sns.boxplot(data['rooms'], palette='deep')
plt.xticks(np.arange(0,20,1))
plt.xlabel('количество комнат')
plt.xlim(0, 20)
plt.title('Диаграмма размаха количества комнат')
plt.show()

# %%
# Описание столбца
data['rooms'].describe()
# Out:
# count   23565.00
# mean        2.07
# std         1.08
# min         0.00
# 25%         1.00
# 50%         2.00
# 75%         3.00
# max        19.00
# Name: rooms, dtype: float64

# %%
# График распределения комнат
plt.figure(figsize=(8, 4))
sns.distplot(data['rooms'],kde=False, bins=20, color='darkblue')
plt.xticks(np.arange(0,10,1))
plt.yticks(np.arange(0,8500,1000))
plt.xlim(0,10)
plt.ylim(0,8500)
plt.grid(True)
plt.title('Диаграмма распределения количества комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Частота')
plt.show()

# %%
data.query('rooms == 0').head()
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 144             1  2450000.00       27.00           2017-03-30      0
# 349             4  2320000.00       25.00           2017-09-27      0
# 440             8  2480000.00       27.11           2018-03-12      0
# 508             0  3375000.00       34.40           2017-03-28      0
# 608             2  1850000.00       25.00           2019-02-20      0
#
#      ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 144            2.50            24        15.50      2         False    True
# 349            2.50            14        17.00      1         False   False
# 440            2.50            17        24.75      4         False    True
# 508            2.50            26        24.30     19         False   False
# 608            2.50            10        16.41      7         False    True
#
#      open_plan  kitchen_area  balcony      locality_name  airports_nearest  \
# ...

# %%
data.query('rooms > 15').sort_values('rooms') # Крайние значения по числу комнат
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 18848             6 28500000.00      270.00           2015-03-02     16
# 14498             6 32250000.00      374.60           2018-06-09     19
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 18848            3.00             4       180.00      4         False   False
# 14498            2.50             5       264.50      2         False   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 18848      False         13.00        1  Санкт-Петербург          23575.00
# 14498      False         27.60        0  Санкт-Петербург          19497.00
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 18848              4142.00              1.00         516.00              0.00
# 14498              3574.00              0.00            nan              2.00
#
# ...

# %%
data['extreme_rooms'] = (
    data['rooms'] > border_markers('rooms')[1]) | (data['rooms'] < 1)
print('Явные студии',data.query('rooms == 0').count()[4])
print('Многокомнатные',data.query('rooms > 6').count()[4])
# Out:
# Явные студии 194
# Многокомнатные 90

# %% [markdown]
# <br>Минимальное количество комнат у 194 квартир, 0.82% от выборки, это вероятнее всего студии, даже если нет отметки в соответсвующем столбце. Одни пользователи ставят 0 комнат, другие 1. Часть отмечает флаг - студия.
# <br>Максимальное количество комнат - 19, вероятно это старый фонд, т.к. в 3.5 км. от центра
# <br>Количество многокомнатных квартир - 90, 0.38% от выборки, это реальные квартиры но очень редкие.
# <br>50% квартир имеют от 1 до 3 комнат, средняя квартира - 2 комнаты.
# <br>99% квартир имеют от 1 до 6 комнат
# <br>Как и общая площадь, количество комнат - следствие разных строительных тенденций разных эпох.

# %% [markdown]
# #### Высота потолков

# %%
print('Границы крайних значений высоты потолков:',border_markers('ceiling_height'))
# Out:
# Границы крайних значений высоты потолков: [2.1999999999999997, 3.0000000000000004]

# %%
# График размаха высоты потолков
plt.figure(figsize=(14, 2))
sns.boxplot(data['ceiling_height'], palette='deep')
plt.xticks(np.arange(0,9,0.5))
plt.xlabel('Высота потолков в м.')
plt.xlim(0, 9)
plt.title('Диаграмма размаха высот потолков')
plt.show()

# %%
# Описание столбца
data['ceiling_height'].describe()
# Out:
# count   23565.00
# mean        2.67
# std         1.00
# min         1.00
# 25%         2.50
# 50%         2.50
# 75%         2.70
# max       100.00
# Name: ceiling_height, dtype: float64

# %%
# График распределения высоты потолков
plt.figure(figsize=(10, 4))
sns.distplot(data['ceiling_height'], kde=False, bins=400, color='darkblue')
plt.xticks(np.arange(0,6,0.5))
plt.xlim(2,6)
plt.grid(True)
plt.title('Диаграмма распределения высоты потолков')
plt.xlabel('Высота потолков в м.')
plt.ylabel('Частота')
plt.show()

# %%
data.query('ceiling_height < 2.40') # Оценка ненормативных потолков
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 227              13  2200000.00       47.00           2018-01-12      3
# 552              11  2999000.00       33.50           2017-03-30      1
# 1582              4  4100000.00       45.60           2016-01-13      2
# 2572              4  2400000.00       62.00           2018-12-27      3
# 4212              1  2120000.00       35.43           2017-12-18      1
# 5498             17  2200000.00       56.00           2018-04-02      2
# 5712              5  1500000.00       42.80           2017-08-14      2
# 5850              9  1650000.00       35.50           2018-05-29      1
# 11352             4  3300000.00       36.00           2017-06-18      1
# 12755             2  1400000.00       22.50           2017-09-21      1
# 16446             6 12300000.00       88.30           2019-03-12      3
# 16884             0  1500000.00       33.00           2018-10-03      1
# ...

# %%
data.query('ceiling_height > 6').head() # Оценка сверхвысоких потолков
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 355             17  3600000.00       55.20           2018-07-12      2
# 3148            14  2900000.00       75.00           2018-11-12      3
# 3474             3  1400000.00       30.00           2018-03-16      1
# 4643             0  4300000.00       45.00           2018-02-01      2
# 4876             7  3000000.00       25.00           2017-09-27      0
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 355            25.00             5        32.00      2         False   False
# 3148           32.00             3        53.00      2         False   False
# 3474            8.00             5        15.30      2         False   False
# 4643           25.00             9        30.00      2         False   False
# 4876           27.00            25        17.00     17         False   False
#
# ...

# %%
data['extreme_ceiling'] = (
    data['ceiling_height'] > 4) | (data['ceiling_height'] < 2.5)
print('Потолки ниже нормы',data.query('ceiling_height < 2.5').count()[6])
print('Аномально высокие потолки',data.query('ceiling_height > 4').count()[6])
# Out:
# Потолки ниже нормы 73
# Аномально высокие потолки 75

# %% [markdown]
# Минимальные 1 м. и самые высокие потолки в 100 м. - явные ошибки в данных по логике.
# Доля квартир с потолками ниже официальной нормы - 73, 0.3%, среди них значения от 2 до 2.47 м, такие потолки возможны в либо в нетипичных строениях старого фонда, либо в частных или сельских домах.
# Доля квартир с экстремально высокими потолками - 75, 0.31% если судить по двухзначным значениям, вероятна ошибка заполнения в появлении лишнего 0 вместо дробного значения.
# 50% квартир имеют потолки высотой от 2.5 до 2.7 метров, средняя высота также около 2.5
# Потолки высотой более 3 метров - встречаются не часто, это характерно для старого фонда в исторической части
# Более 99 % квартир имеют потолки от 2.5 до 4 метров
# Данные содержали большое количество пропусков - 38%, они были приведины к минимальной норме в 2.5 м. Как правило, большая высота потолка - преимущество, увеличивающее оценку, поэтому такие пропуски либо говорят о том что пользователь не выделял высоту потолка, значит она средняя или нормативная. Либо, большая доля пропусков - непрогрузившиеся данные.

# %% [markdown]
# ### Время продажи квартиры

# %%
print('Границы кайних значений времени продажи:',border_markers('days_exposition'))
# Out:
# Границы кайних значений времени продажи: [1.0, 510.0]

# %%
# Нрафик размаха срока размещения
plt.figure(figsize=(14, 2))
sns.boxplot(data['days_exposition'], palette='deep')
plt.xticks(np.arange(0,1580,30),rotation=90)
plt.xlabel('Срок экспозиции в днях')
plt.xlim(0, 1600)
plt.title('Диаграмма размаха срока эксрозиции')
plt.show()

# %%
# Описание столбца
data['days_exposition'].describe() # Описание распределения
# Out:
# count   20394.00
# mean      180.74
# std       219.73
# min         1.00
# 25%        45.00
# 50%        95.00
# 75%       231.00
# max      1580.00
# Name: days_exposition, dtype: float64

# %%
# Гистограмма распределения срока экспозиции
plt.figure(figsize=(16, 4))
sns.distplot(data['days_exposition'], kde=False, bins=500, color='darkblue')
plt.xticks(np.arange(0,510,10),rotation=90)
plt.xlim(0,510)
plt.grid(True)
plt.title('Диаграмма распределения срока экспозиции')
plt.xlabel('Срок экспозиции в днях.')
plt.ylabel('Частота')
plt.show()

# %%
# Распределение ограниченное двумя месяцами
plt.figure(figsize=(16, 4))
sns.distplot(data['days_exposition'], kde=False, bins=2000, color='darkblue')
plt.xticks(np.arange(0,61,1),rotation=90)
plt.xlim(0,61)
plt.grid(True)
plt.title('days_exposition 2 месяца')
plt.xlabel('Срок экспозиции в днях.')
plt.ylabel('Частота')
plt.show()

# %%
data['extreme_exposition'] = (
    data['days_exposition'] > border_markers('days_exposition')[1]) | (data['days_exposition'] < 2.5)
print('Крайне длинный срок экспозиции',data.query('days_exposition > 510').count()[22])
print('Крайне короткий срок экспозиции',data.query('days_exposition <= 1').count()[22])
print('Срок экспозиции меньше недели',data.query('days_exposition <= 7').count()[22])
# Out:
# Крайне длинный срок экспозиции 1667
# Крайне короткий срок экспозиции 1
# Срок экспозиции меньше недели 845

# %%
too_long_exposition = data.query('days_exposition > 510')
display(too_long_exposition.sample(10, random_state=1))
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 13044            11  9990000.00      108.00           2015-02-10      3
# 18104             2 16775132.00      134.50           2016-10-07      4
# 21544            10 14400000.00      105.30           2017-02-17      3
# 11955             4 11400000.00       76.00           2014-12-09      2
# 8829             15  5050000.00       40.00           2015-06-09      1
# 19505             5  3000000.00       60.00           2015-03-11      3
# 3428              6  5930908.00       89.60           2015-03-10      3
# 12706             4 32524000.00      129.10           2015-01-21      3
# 6014              5  2650000.00       58.70           2015-01-23      3
# 3655              9  3150000.00       35.70           2015-12-24      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 13044            3.05             5        56.00      4         False   False
# ...

# %% [markdown]
# <br>В столбце присутствуют 13.42% пропусков значений, т.е. данные не усреднялись
# <br>Минимальный срок размещения - 1 день, есть одно такое объявление.
# <br>Максимальный срок размещения - 1580 дней, более четырех лет.
# <br>50% всех квартир были в экспозиции от 45 до 231 дня, средний срок показа объявления 95 дней
#
# <br>На графике видны всплески значений  около 45, 60 и 90 дня экспозиции. Необходимо подчеркнуть что данные столбца - имеено срок показа объявления, это не значит что квартира продана за этот срок. Наличие всплесков в таких днях возможно имеют техническую причину для снятия. Вероятно это связано правилами сервиса по срокам показа объявлений, которые в свою очередь могут изменятся со временем. В целом, длинный срок экспозиции связан с оценкой квартиры, на которую в свою очередь влияют кроме параметров жилья, в разной степени - множество других фактров. В случае если оценка не в рынке на конкретный этап времени, срок экспозиции удлиннаяется.
# <br>Рекомендация - выяснить у поставщика данных, что могут означать выбросы около 45,60,90 дней, с чем это возможно связано.

# %% [markdown]
# <div class="alert alert-warning" style= "background-color: #d3e5f0" style="border-radius: 15px">
#     Экстремальные значения согласно статистическому методу IQR*1.5 (потора межквантильного размаха) в отношении срока показа объявления - ранее 1 дня и более 510 дней. С точки зрения статистики это только показатель возможности выброса. Квартира вполне может быть продана и за один день, особенно если оценена ниже рынка, также она может продаваться очень долго, если у нее завшенная оценка или это достаточно уникальный объект. Неисключено, что слишком долгие сроки публикации объявлений - техническая ошибка. Т.к в столбце уже есть 13% пропусков, удаление крайних значений этого столбца (еще 8%) может исказить картину. Столбец оставлен как есть.
#     <span style='color:blue'></span></div>

# %% [markdown]
# ### Редкие и экстремальные значения

# %%
data.head() # Проверка текущего датафрейма
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20 13000000.00      108.00           2019-03-07      3
# 1             7  3350000.00       40.40           2018-12-04      1
# 2            10  5196000.00       56.00           2015-08-20      2
# 3             0 64900000.00      159.00           2015-07-24      3
# 4             2 10000000.00      100.00           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16        51.00      8         False   False
# 1            2.50            11        18.60      1         False   False
# 2            2.50             5        34.30      4         False   False
# 3            2.50            14        94.95      9         False   False
# 4            3.03            14        32.00     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
# Очистка датафрейма от экстремальных значений
normalized_data = data[(data['extreme_area'] == False) & 
     (data['extreme_price'] == False) &
     (data['extreme_rooms'] == False) &
     (data['extreme_ceiling'] == False)].reset_index(drop=True)

# %%
print('Доля нормализованных строк от оригинального датафрейма: {:.2%}'. format(len(normalized_data) / len(data)))
# Out:
# Доля нормализованных строк от оригинального датафрейма: 88.21%

# %%
# Scatterplot для параметров
sns.pairplot(normalized_data, 
                 vars=['total_area', 'last_price', 'rooms', 'ceiling_height'],
                 height=3)
plt.title('Диаграмма параметров влияющих на цену')
# Out:
# Text(0.5, 1, 'Диаграмма параметров влияющих на цену')

# %%
normalized_data_original = normalized_data.copy()
normalized_data.describe() # Оценка номализованного датафрейма
# Out:
#        total_images  last_price  total_area    rooms  ceiling_height  \
# count      20786.00    20786.00    20786.00 20786.00        20786.00
# mean           9.73  4864782.20       52.98     1.93            2.61
# std            5.54  2146308.20       17.58     0.87            0.19
# min            0.00  1000000.00       20.00     1.00            2.50
# 25%            6.00  3390000.00       39.20     1.00            2.50
# 50%            9.00  4450000.00       49.70     2.00            2.50
# 75%           14.00  5999000.00       63.20     3.00            2.70
# max           50.00 11866860.00      114.20     6.00            4.00
#
#        floors_total  living_area    floor  kitchen_area  balcony  \
# count      20786.00     20786.00 20786.00      20786.00 20786.00
# mean          10.83        30.34     5.91          9.50     0.59
# std            6.61        12.63     4.90          3.63     0.94
# min            1.00         2.00     1.00          0.00     0.00
# ...

# %% [markdown]
# <br>В качестве основы для экстремальных значений взят IQRx1.5 т.е. 1.5 50% значений от каждой границы 50% значений. С корректировкой границ на основе анализа каждого столбца с параметрами в пункте 4.1:
# <br>Для площади - менее 20 и более 114 кв.м, - 5.39%
# <br>Для цены - дешевле 1000000 и дороже 1187500 р. - 9.03%
# <br>Для количества комнат - менее 1 и более 6 - 1.2%
# <br>Для высоты потолков - менее 2.5 и более 4 м. - 0.61%
# Наибольшой коррекции подверглись параметры с самым широким распределением, в основном корректировалась нижняя граница наблюдений, исходя из данных графиков.
# Scatter plot для нормализированых данных позволяет увидеть отсутствие экстремальных значений, при том что нормализированный датафрейм отличается от оригинального на 11,79% строк

# %% [markdown]
# ### Зависимость цены квартиры

# %%
# Распределение цены от площади и расстояния до центра
fig, [ax1, ax2] = plt.subplots(1, 2, sharey=True, figsize=(16, 5), gridspec_kw={'wspace': 0})
# Зависимость цены от площади
ax1.set_title('Зависимость цены от площади')
ax1.set_ylabel('Цена, 10 млн.р.')
ax1.set_xlabel('Общая площадь кв.м')
ax1.text(20, 8000000, 
         'коэф. корреляции: ' + str(round(normalized_data['last_price'].corr(normalized_data['total_area']), 2)))
hb1 = ax1.hexbin(normalized_data['total_area'], normalized_data['last_price'], cmap='mako_r')
cb1 = fig.colorbar(hb1, ax=ax1)
cb1.set_label('Частота')
# Зависимость цены от расстояния до центра
ax2.set_title('Зависимость цены от расстояние до центра города')
ax2.set_ylabel('Цена, 10 млн.р.')
ax2.set_xlabel('Расстояние до центра города, м')
ax2.text(30000, 6000000, 
         'коэф. корреляции: ' + str(round(normalized_data['last_price'].corr(normalized_data['cityCenters_nearest']), 2)))
hb2 = ax2.hexbin(normalized_data['cityCenters_nearest'], normalized_data['last_price'], cmap='rocket_r')
cb2 = fig.colorbar(hb2, ax=ax2)
cb2.set_label('Частота')
plt.tight_layout(pad=3)
plt.show()

# %% [markdown]
# <br>Зависимость цены от площади - наблюдается, кореляция выше среднего положительная (0.7), цена увеличивается с увеличением площади.
# <br>Зависимость цены от расстояния до центра, корреляция слабая обратная (-0.35), цена слабо уменьшается с увеличением расстояния от центра, после 10 км, стоновиться практически не чувствительной к расстоянию до центра. Это напрямую звязано с развитием инфраструктуры окраин и формированием локальных центров - пригородов и районных центров.

# %%
# Зависимость цены от количества комнат
rooms_qty = normalized_data.pivot_table(index = 'rooms', values = 'last_price', aggfunc = ['mean','median','count'])
rooms_qty.columns = ['mean','median','count']
rooms_qty.sort_values('median')
# Out:
#             mean     median  count
# rooms
# 1     3799666.32 3600000.00   7809
# 2     5060039.31 4700000.00   7405
# 3     5996572.88 5700000.00   4819
# 4     6695756.00 6700000.00    686
# 5     7219682.54 7600000.00     63
# 6     8141000.00 7982000.00      4

# %%
# График зависимости цены от количества комнат
sns.catplot(x="rooms", y="last_price", kind="boxen", data=normalized_data, palette='bright')
plt.title('Диаграмма размаха цены по количеству комнат')
# Out:
# Text(0.5, 1, 'Диаграмма размаха цены по количеству комнат')

# %% [markdown]
# Зависимость цены от количества комнат присутствует, она растет с увеличением количичтва комнат, однако начиная с 4 комнатных квартир такая зависимость слабеет, в среднем цена 3 комнатной квартиры ниже чем 4 комнатной, но недорогие квартиры обоих категорий могут продаваться по одной цене. 6 комнатные квартиры имеют лостаточно короткий размах по цене, что может говорить об узости сегмента с таким количеством комнат.

# %%
# Зависимость цены от категории этажности
floor_group = normalized_data.pivot_table(index = 'floor_cat', values = 'last_price', aggfunc = ['mean','median','count'])
floor_group.columns = ['mean','median','count']
floor_group.sort_values('median')
# Out:
#                 mean     median  count
# floor_cat
# первый    4205047.68 3900000.00   2639
# последний 4518324.59 4100000.00   2847
# другой    5043043.91 4600000.00  15300

# %%
# График зависимости цены от категории этажности
sns.catplot(x='floor_cat', y='last_price', kind="box", data=normalized_data, palette='bright')
plt.title('Диаграмма размаха цены по категориям этажности')
# Out:
# Text(0.5, 1, 'Диаграмма размаха цены по категориям этажности')

# %% [markdown]
# Первые и последние этажи стоят дешевле чем все остальные. Причем первые этажи немного дешевле последних в верхнем ценовом сегменте.

# %%
weekday_group = normalized_data.pivot_table(index = 'weekday', values = 'last_price', aggfunc = ['mean','median','count'])
weekday_group.columns = ['mean','median','count']
weekday_group.sort_values('median')
# Out:
#               mean     median  count
# weekday
# 3       4876027.11 4400000.00   3728
# 4       4847828.73 4400000.00   3530
# 5       4795005.82 4400000.00   1707
# 6       4798640.79 4400000.00   1495
# 0       4853179.55 4450000.00   3181
# 1       4906047.69 4500000.00   3680
# 2       4899692.84 4500000.00   3465

# %%
# График зависимости цены от дня недели
sns.catplot(x='weekday', y='last_price', kind='box', data=normalized_data, palette='bright')
plt.title('Диаграмма размаха цены по дням недели')
# Out:
# Text(0.5, 1, 'Диаграмма размаха цены по дням недели')

# %% [markdown]
# Медианная цена квартир немного снижается к концу недели.

# %%
# Средние по месяцам
month_group = normalized_data.pivot_table(index = 'month', values = 'last_price', aggfunc = ['mean','median','count'])
month_group.columns = ['mean','median','count']
month_group.sort_values('median')
# Out:
#             mean     median  count
# month
# 6     4701317.69 4210000.00   1556
# 5     4841494.75 4362500.00   1114
# 7     4836969.58 4399000.00   1474
# 8     4865713.52 4400000.00   1530
# 10    4840539.30 4425000.00   1889
# 1     4844947.64 4450000.00   1302
# 2     4867454.03 4450000.00   2326
# 9     4953888.59 4492500.00   1714
# 3     4831140.10 4499500.00   2280
# 11    4898120.18 4500000.00   2062
# 12    4904668.92 4500000.00   1444
# 4     4952087.61 4595000.00   2095

# %%
# График зависимости цены от месяца
sns.catplot(x='month', y='last_price', kind='box', data=normalized_data, palette='bright')
plt.title('Диаграмма размаха цены по месяцам')
# Out:
# Text(0.5, 1, 'Диаграмма размаха цены по месяцам')

# %% [markdown]
# Наблюдается небольшая сезонность в медианной стоимости квартир по месяцам. Низкий сезон - июнь и декабрь. С июля цены начинают расти всю осень и зиму и на пик выходят в апреле.

# %%
# Средние по годам
year_group = normalized_data.pivot_table(index = 'year', values = 'last_price', aggfunc = ['mean','median','count'])
year_group.columns = ['mean','median','count']
year_group.sort_values('median')
# Out:
#            mean     median  count
# year
# 2016 4775568.14 4300000.00   2403
# 2017 4783253.01 4300000.00   7212
# 2018 4823702.62 4450000.00   7591
# 2015 5193297.57 4850000.00    962
# 2019 5151541.94 4850000.00   2532
# 2014 5703124.95 5425000.00     86

# %%
# График зависимости цены от года
sns.catplot(x='year', y='last_price', kind='box', data=normalized_data, palette='bright')
plt.title('Диаграмма размаха цены по годам')
# Out:
# Text(0.5, 1, 'Диаграмма размаха цены по годам')

# %% [markdown]
# Медианная цена падала с 2014 по 2016, в 2017 и 2018 держалась на примерно одном уровне и начала расти в 2019 году. Такая динамика связана с увеличением количества объявлений и с экономическими циклами в эти годы и колебаниями ставок по кредитам. Будучи высокими в 2014 и 2015 году с 2016 года ставки начали падать что вызвало повышение спроса и цен соответственно.

# %%
# Построение корреляционной матрицы по параметрам квартиры в регионе
pd.set_option('display.float_format', lambda x: '%.2f' % x)
corr_data = data[['last_price', 'total_area', 'rooms', 'ceiling_height']]
corr_matrix = corr_data.corr()
corr_matrix
# Out:
#                 last_price  total_area  rooms  ceiling_height
# last_price            1.00        0.65   0.36            0.07
# total_area            0.65        1.00   0.76            0.08
# rooms                 0.36        0.76   1.00            0.05
# ceiling_height        0.07        0.08   0.05            1.00

# %%
# График корреляционной зависимости в регионе
plt.figure(figsize=(6, 5))
sns.heatmap(corr_matrix, linewidth = 0.5 , cmap = 'coolwarm',annot=True, linewidths=.5) 
plt.xticks(va='center')
plt.yticks(va='center')
plt.title( "Корреляция параметров квартиры в центре СПб" )
plt.show()

# %% [markdown]
# ### 10 населенных пунктов с наибольшим числом объявлений

# %%
# Вывод таблицы средних значений по количеству в городах
mean_price_per_sqm = normalized_data.pivot_table(index='locality_name', values='price_per_sqm', aggfunc=['count', 'mean'])
mean_price_per_sqm.columns = ['count', 'mean']
mean_price_per_sqm.sort_values('count', ascending=False).head(10)
# Out:
#                    count      mean
# locality_name
# Санкт-Петербург    13362 105520.05
# Мурино               558  85505.11
# Кудрово              446  94900.63
# посёлок Шушары       432  78303.01
# Всеволожск           385  67235.11
# Колпино              334  75240.84
# Пушкин               331 100321.49
# посёлок Парголово    321  90479.24
# Гатчина              301  68867.40
# Выборг               221  58852.61

# %% [markdown]
# Первый в числе городов с самым большим количеством объявлений и самой большой ценой среднего увадаратного метра- Санкт-Петербург.
# Все города кроме последнего в списке - либо ближайшие пригороды, являющиеся официальными городскими районами, либо пригороды относящиеся к Лен.области.
# Самый дорогой из пригородных районов города - Пушкин, имеющий плюс в виде дворцов, парков и исторической застройки.
# Замыкает список - Выборг, единственный город Лен.области из списка расположенный на удалении от города (140 км). Сравнительно высокие цены в Выборге можно объяснить расположением на Карельском перешейке, который считается экологически чистым районом с великолепной природой. Рядом финская граница и трансграничные потоки, выход к морю.

# %% [markdown]
# ### Расстояние до центра Санкт-Петербурга

# %%
#Приведение расстояния до центра в км, отделение экстремальных значений
data['city_center_km'] = round(data['cityCenters_nearest'] / 1000, 0)
data['city_center_km'] = data['city_center_km'].astype('int', errors='ignore')
normalized_data = data[(data['extreme_area'] == False) & 
     (data['extreme_price'] == False) &
     (data['extreme_rooms'] == False) &
     (data['extreme_ceiling'] == False)].reset_index(drop=True)
# Выборка локации Санк-Петербурга и группировка цены по расстоянию до центра
normalized_data.loc[(normalized_data['locality_name'] == 'Санкт-Петербург') & 
                    (normalized_data['city_center_km'].notna()), 'city_center_km']
spb_data = normalized_data.query('locality_name == "Санкт-Петербург"')
spbcenter_nearest = spb_data.pivot_table(index='city_center_km', values=['price_per_sqm', 'last_price'], aggfunc='mean')
pd.set_option('display.float_format', lambda x: '%.0f' % x)
spbcenter_nearest
# Out:
#                 last_price  price_per_sqm
# city_center_km
# 0                  7622500         111239
# 1                  8160793         119451
# 2                  7936630         115696
# 3                  7200847         109505
# 4                  7462481         116619
# 5                  7608971         120833
# 6                  7079918         122279
# 7                  6640908         116425
# 8                  6609445         115846
# 9                  5544912         106530
# 10                 5401708         108374
# 11                 5280628         104407
# 12                 5304934         105574
# 13                 5526493         105995
# 14                 5283368         103191
# 15                 5264996         102454
# 16                 5113756          99296
# 17                 4878208          95442
# 18                 4651821          96123
# 19                 4849866          97494
# 20                 6051817         101381
# ...

# %%
# Построение диограммы распределения цены в зависимости от расстояния для центра
sns.set_style("whitegrid")
sns.relplot(
    x=spbcenter_nearest.index,
    y='last_price', data=spbcenter_nearest,
    kind='scatter', size="last_price",sizes=(0, 70),
    height=5, aspect=1.5, color='red')
plt.xticks(np.arange(0,35,1))
plt.yticks(np.arange(3000000,8500000,500000))
plt.annotate('цена 6609445', xy=(8, 6500000), xytext=(12, 6520000),
            arrowprops=dict(facecolor='darkblue', shrink=0.05))
plt.annotate('цена 5544912', xy=(9, 5500000), xytext=(0, 5520000),
            arrowprops=dict(facecolor='darkblue', shrink=0.05))
plt.title('Зависимость средней цены от расстояния до центра Санкт-Петербурга')
plt.ylabel('Цена недвижимости, руб.')
plt.xlabel('Расстояние до центра, км')
plt.show()

# %%
# Построение диограммы распределения стоимости кв.м. в зависимости от расстояния для центра
sns.set_style("whitegrid")
sns.relplot(
    x=spbcenter_nearest.index,
    y='price_per_sqm', data=spbcenter_nearest,
    kind='line',
    height=5, aspect=1.5, color='red')
plt.xticks(np.arange(0,35,1))
plt.yticks(np.arange(50000,150000,10000))
plt.annotate('115846', xy=(8, 115143), xytext=(12, 116143),
            arrowprops=dict(facecolor='darkblue', shrink=0.05))
plt.annotate('106530', xy=(9, 107174), xytext=(0, 108174),
            arrowprops=dict(facecolor='darkblue', shrink=0.05))
plt.title('Зависимость цены среднего кв.м от расстояния до центра Санкт-Петербурга')
plt.ylabel('Средняя цена кв.м., руб.')
plt.xlabel('Расстояние до центра, км')
plt.show()

# %% [markdown]
# <br>На диаграммах распределения цены и стоимости кв.м. видна разница между 9 и 10 км от центра, в этом промежутке средняя цена падает более чем на 1 млн.р с 6609445 до 5544912 р.Также в этом промежутке падает средняя стоимость кв.м. почти на 8 тыс.р с 115846 до 106530 р.Следовательно центр города можно ограничить 8 км.
# <br>Заментно также что цена вновь падает после 20 км, что примерно соответствет границам города и ближайших пригородов

# %% [markdown]
# ### Анализ квартир в центре Санкт-Петербурга

# %%
# Выборка центра города ограниченного 8 км
spb_center = normalized_data[(normalized_data['city_center_km'] <= 8) & (normalized_data['locality_name'] == 'Санкт-Петербург')]

# %%
# Оценка размаха площади в центре
print(spb_center['total_area'].describe())
plt.figure(figsize=(16, 2))
sns.boxplot(spb_center['total_area'], color='tab:blue')
plt.xticks(np.arange(0,130,5))
plt.title('Диаграмма размаха по площади')
plt.xlabel('Общая площадь, кв. м')
plt.show()
# Out:
# count   2617
# mean      64
# std       20
# min       20
# 25%       47
# 50%       62
# 75%       78
# max      114
# Name: total_area, dtype: float64

# %% [markdown]
# 50% площади всех квартир в центре от 46 до 78 кв.м., средняя площадь - 63 кв.м.
# В сравнении с основной выборкой где 50% площади - от 40 до 69.7 кв.м. и средняя площадь 60 кв.м можно сказать что в среднем квартиры в центре имеют большую площадь, средняя больше на 5%, медианная на 17%

# %%
# Оценка размаха цены в центре
print(spb_center['last_price'].describe())
plt.figure(figsize=(16, 2))
sns.boxplot(spb_center['last_price'], color='tab:red')
plt.xticks(np.arange(0,13000000,500000))
plt.title('Диаграмма размаха цены')
plt.xlabel('Цена, 10 млн рублей')
plt.show()
# Out:
# count       2617
# mean     7231756
# std      2136581
# min      1600000
# 25%      5650000
# 50%      7080000
# 75%      8812000
# max     11866860
# Name: last_price, dtype: float64

# %%
# Вывод среднего и медианы для цены за кв.м
print(data['price_per_sqm'].mean())
print(spb_center['price_per_sqm'].mean())
# Out:
# 99405.83717377466
# 117626.81077569735

# %% [markdown]
# Стоимость 50% квартир в центре от 5.55 до 8.76 млн.р. средняя цена 7.17 млн.р.
# В сравнении с общей выборкой по региону квартиры в центре СПб дороже на 50% в медианном значении и на 10% в среднем.
# Квадратный метр в центре в среднем дороже на 18% чем в остальных локациях. В центре преобладает исторический старый фонд, либо бизнес-класс в современной застройке.

# %%
# Оценка количества комнат в центре
print(spb_center['rooms'].describe())
plt.figure(figsize=(16, 2))
sns.boxplot(spb_center['rooms'], color='tab:green')
plt.title('Диаграмма размаха')
plt.xlabel('Число комнат, шт.')
plt.show()
# Out:
# count   2617
# mean       2
# std        1
# min        1
# 25%        2
# 50%        2
# 75%        3
# max        6
# Name: rooms, dtype: float64

# %% [markdown]
# 50% квартир в центре имеют от 2 до 6 комнат, в отличии от общей выбокой где это значение от 1 до 3. В центре количество квартир больше чем в общей выборке, что связано наличием большой части старого фонда, преобладанием исторических архитектурных тенденций.

# %%
#Оценка высоты потолков в центре
print(spb_center['ceiling_height'].describe())
plt.figure(figsize=(16, 2))
sns.boxplot(spb_center['ceiling_height'], color='tab:grey')
plt.title('Диаграмма размаха высоты потолков')
plt.xlabel('Цена, 10 млн рублей')
plt.show()
# Out:
# count   2617
# mean       3
# std        0
# min        2
# 25%        2
# 50%        3
# 75%        3
# max        4
# Name: ceiling_height, dtype: float64

# %% [markdown]
# 50% квартир в центре имеют потолки от 2.5 до 3 м, средняя высота - 2.8 м
# Это выше чем в общей выборке на 8% в медианном значении. Трехметровы потолки в центре, особенно в старом фонде - не редкость в отличии от спальных районов, где этот показатель характерен скорее для бизнес-класса.

# %%
# Оценка срока размещения объявления в центре
print(spb_center['days_exposition'].describe())
plt.figure(figsize=(16, 2))
sns.boxplot(spb_center['days_exposition'], color='yellow')
plt.xticks(np.arange(0,500,10))
plt.title('Диаграмма размаха срока публикации')
plt.xlabel('Срок размещения публикации, дней')
plt.xlim(0, 450)
plt.show()
# Out:
# count   2304
# mean     216
# std      254
# min        3
# 25%       49
# 50%      115
# 75%      285
# max     1497
# Name: days_exposition, dtype: float64

# %% [markdown]
# 50% объявлений в центре имеею срок размещения от 41 до 207 дней, в среднем 139 дней. Половина квартир снимается с продажи до 92 дней, половина позже. В сравнении с общей выборкой где 50% обявлений размещаются от 45 до 231 дня и в среднем 180 дней, можно сделать вывод что квартиры в центре в целом ликвиднее, даже при более высокой цене, сказывается ограниченные возможности застройки в центре, туристическая привлекательность, а значит возможность зарабатывать на этом. Престижность, соответственно спрос на видовые квартиры - вне сомнений.

# %%
# График зависимости цены от количества комнат
sns.catplot(x="rooms", y="last_price", kind="boxen", data=spb_center, palette='bright')
plt.title('Диаграмма размаха цен по количеству комнат')
plt.grid(axis = 'y')

# %% [markdown]
# В центре города с увеличением количества комнат растет цена как и в общей выборке, однако в центре почти по одной цене выставляются 5 и 6 комнатные квартиры верхнего ценового сегмента, но размах цены у 6 квартир в 2 раза меньше чем у 5 комнатных.
# В отличии от общей выборки где такое происходило с 3 и 4 комнатными квартирами ро нижней цене. Причем иногда 6 квартиры верхнего ценового сегмента могут быть дешевле 5 комнатных.

# %%
# График зависимости цены от категории этажности
sns.catplot(x='floor_cat', y='last_price', kind='boxen', data=spb_center, palette='bright')
plt.title('Диаграмма размаха цен по категориям этажности')
plt.grid(axis = 'y')

# %% [markdown]
# В зависимости цены от категории этажности в центре наблюдается картина противоположная общей выборке: первый и последнии этажи стоят дороже чем остальные, причем первый этажи чуть дороже последних.

# %%
# Графиу зависимости цены в центре от удаления от центра
sns.set_style("whitegrid")
sns.relplot(
    x='city_center_km',
    y='last_price', data=spb_center,
    kind='line',
    height=5, aspect=1.5, color='red')
plt.title('Зависимость цены от удаления от центра')
# Out:
# Text(0.5, 1, 'Зависимость цены от удаления от центра')

# %% [markdown]
# Зависимость цены от расстояния от центра немного растет до 1 км, далее падает до 3 км, после чего вновь небольшой подьем и снова падение до условной границы в 8 км. Провал в районе 3 км можно обяснить случайным попаданием квартир в пятно чуть более низкого ценового сегмента. Например на этой дистанции от Дворцовой площади могут в одной стороне находится топовые локации Невского проспекта и более дешевые локации в Коломне.

# %%
# График зависимости цены от дня размещения
sns.catplot(x='weekday', y='last_price', kind='boxen', data=spb_center, palette='bright')
plt.title('Диаграмма размаха цен по дням недели')
plt.xlabel('Дни недели')
plt.grid(axis = 'y')

# %% [markdown]
# Зависимость цены от дня подачи объявления в центр, повторяют тенденцию общей выборки: цены размещаемых объялений незначительно уменьшаются с понедельника в течении всей недели. Однако в центре есть исключения - пятница суббота и воскресенье, в эти дни цена слегка выше.

# %%
# График зависимости цены от месяца размещения
sns.catplot(x='month', y='last_price', kind='boxen', data=spb_center, palette='bright')
plt.title('Диаграмма размаха цен по месяцам')
plt.xlabel('Месяцы')
plt.grid(axis = 'y')

# %% [markdown]
# Сезонность в центре, проявляется не так как в общей выборке где низкий сезон - май, июнь. В центре сезонность размыта: пики цен размещений приходятся на март, с июля по сентябрь и ноябрь. А декабрь - низкий сезон.

# %%
# График зависимости цены от месяца размещения
sns.catplot(x='year', y='last_price', kind='boxen', data=spb_center, palette='bright')
plt.title('Диаграмма размаха цен по годам')
plt.xlabel('Года')
plt.grid(axis = 'y')

# %% [markdown]
# Цены размещения в центре по годам с 2014 по 2019 были на одном уровне. Это возможно также говорит о хорошей ликвидности квартир в центре, который позволил ценам избежать провала в послекризисном 2015, когда цены в основной выборке падали. В 2019 нижняя планка цен для квартир в центре заментно подтянулась вверх.

# %%
# Построение корреляционной матрицы по параметрам квартиры в центре
pd.set_option('display.float_format', lambda x: '%.2f' % x)
corr_data_spb = spb_center[['last_price', 'total_area', 'rooms', 'ceiling_height']]
corr_matrix_spb = corr_data_spb.corr()
corr_matrix_spb
# Out:
#                 last_price  total_area  rooms  ceiling_height
# last_price            1.00        0.71   0.45            0.20
# total_area            0.71        1.00   0.79            0.24
# rooms                 0.45        0.79   1.00            0.21
# ceiling_height        0.20        0.24   0.21            1.00

# %%
# График корреляционной зависимости в центре
plt.figure(figsize=(6, 5))
sns.heatmap(corr_matrix_spb, linewidth = 0.5 , cmap = 'coolwarm',annot=True, linewidths=.5) 
plt.xticks(va='center')
plt.yticks(va='center')
plt.title( "Корреляция параметров квартиры в центре СПб" )
plt.show()

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Перед исследованием стояла задача установить параметры для определения рыночной стоимости объектов недвижимости, с целью последующей автоматизации.
# В полученных данных из 23699 строк и 12 столбцов были обнаружены пропуски с разной долей, нелогичные и экстремальные значения. После предобработки данных был проведен исследовательский анализ данных на основе нормализованных данных - 82% от общей выборки, который установил что на рыночную оценку объектов недвижимости влияют:
# <br>1. Общая площадь квартиры
# Цена хорошо коррелирует с общей площадью, зависимость сильная, чем больше площадь, тем выше цена. Зависимость наблюдается как во всей агломерации так и в центре Санкт-Петербурга.
# <br>2. Количество комнат
# Количество комнат увелтчтвает цену, чем их больше тем выше цена, зависимость сильная для 1,2 и 3 комнатных квартир, далее ослабевает, 4 и 5 комнатные квартиры могут продаваться по одним ценам.
# <br>3. Высота потолков
# Зависимость цены от высоты потолков проявляется когда их значения значительно выше средних, около 3 м и более, соответственно многие пользователи этот параметр указывают только если отличается от обычного он добавляет к оценки квартиры.
# <br>4. Локация
# Естесственно цены СПб и пригородов выше чем областные. Среди пригородов по количеству объявлений наиболее высокие цены имеет Пушкин, среди удаленных региональных центров - Выборг
# <br>5. Близость к центру Санкт-Петербура
# Хотя корреляция зависимости цены от центра не сильная, цены в центре города который согласно анализу ограничен радиусом в  8 км, выше в среднем на 10%
# <br>6. Категория этажности
# Последний этаж дороже первого на 9%, любой другой кроме крайних - дороже на 20%
#
# Незачительное влияние на цену могут оказать время размещения объявления, низкий сезон обычно - май июнь, высокий - с начала года по апрель включительно.
#
# 50% квартир имели срок размещения объявления от 45 до 231 дня, в среднем 180 дней.
#
# Было также проведено исследование объявлений с локацией в центре города **ограниченном 8 км**. Оно показало что квартиры в центре в целом дороже и габаритнее, с большей ликвидностью по сравнению с квартирами всего региона, малочувствительные к сезонности, более дорогими первыми и последними этажами по сравнению со всеми остальными.
#
# Выявленные особенности в представленных данных, на которые надо обратить внимание:
#
# Имеются существенные пропуски в данных **связанных с автоматической геопривязкой размещаемых объектов** - в среднем 23% от выборки. Эти пропуски оставлены без изменения. **Небходимо выяснить причины у поставщика данных**.
# Возможно имеются технические причины для снятия объявлений по сроку, выявлены всплески снятий окола 45, 60, 90 дней. Если такие причины есть, необходимо **отмаркировать такие снятия**, для отдельного учета в анализе.

# %% [markdown]
# <div class="alert alert-warning" style= "background-color: #d3e5f0" style="border-radius: 15px"><span style='color:blue'>На основе анализа сформированы параметры метрик типичных квартир в публикуемых объявлениях для региона</span></div>

# %%
# Нормализированы метрики для квартиры по региону
normalized_object = normalized_data.describe()
metrics = normalized_object[['last_price','total_area','rooms','ceiling_height', 'price_per_sqm']]
metrics.iloc[3:]
# Out:
#      last_price  total_area  rooms  ceiling_height  price_per_sqm
# min  1000000.00       20.00   1.00            2.50       13483.10
# 25%  3390000.00       39.20   1.00            2.50       75344.68
# 50%  4450000.00       49.70   2.00            2.50       92961.65
# 75%  5999000.00       63.20   3.00            2.70      109454.30
# max 11866860.00      114.20   6.00            4.00      312240.00

# %% [markdown]
# <div class="alert alert-warning" style= "background-color: #d3e5f0" style="border-radius: 15px"><span style='color:blue'>На основе анализа сформированы параметры метрик типичных квартир в публикуемых объявлениях для центра Санкт-Петербурга</span></div>

# %%
# Нормализированы метрики для квартиры по региону
normalized_object_center = spb_center.describe()
metrics_center = normalized_object_center[['last_price','total_area','rooms','ceiling_height', 'price_per_sqm']]
metrics_center.iloc[3:]
# Out:
#      last_price  total_area  rooms  ceiling_height  price_per_sqm
# min  1600000.00       20.00   1.00            2.50       17391.30
# 25%  5650000.00       46.80   2.00            2.50       96666.70
# 50%  7080000.00       62.00   2.00            2.70      113333.30
# 75%  8812000.00       78.00   3.00            3.00      134854.80
# max 11866860.00      114.20   6.00            4.00      262711.90

# %% [markdown]
# <div class="alert alert-warning" style= "background-color: #d3e5f0" style="border-radius: 15px"><span style='color:blue'>Общая рекомендация: Построение модели автоматического скорринга по параметрам выше. При этом, возможно выделить большим весом общую площадь (цену кв.м), как более коррелирующую с ценой величину, высоту потолков - меньшим как менее коррелирующую. В модели скорринга также нужно учесть категорию этажа. Возможно отдельная модель для центра города ограниченным радиусом вычесленным в исследовании - 8 км. Целью будет автоматизированное выделение квартир, или отдельных параметров, которые отличаются от типичных, для дальнейшей модерации и/или обработки.</span></div>
